# %% [markdown]
#  ## Este notebook visa testar diversos encoders para as imagens de escâner
#
# As imagens já deverão estar "tratadas"/editadas( "tratar" em termos de retirar lixo, como espaço vazio, carreta, caminhão, etc) para deixar somente as bordas do contêiner e seu conteúdo.
#
#  ## Problema a resolver: busca de imagens
#
# Formulação:
#
# Aqui, o objetivo é testar encoders para obter uma representação comprimida das imagens que permita montar um banco de dados para busca de imagens similares. Lembrando que o esperado apenas para ALFSTS são 3000 imagens dia. Num universo de apenas 5 anos, são 3.000x365x5 = 5,5 milhões.
#
# Cada imagem, mesmo que seja apenas um Thumbnail de 150x80 pixels, ocuparia uma média de pouco mais de 2-3KB numa compressão de arquivo JPEG, ou um total de 12-16GB de RAM. No formato matriz, são 150x80x4bytes ou 48KB, ou até 200GB de RAM.
#
# Solução testada neste notebook:
#
# Utilizar autoencoders para aprender uma representação de poucos números float32 (de 100 a 500) ou até 4 vezes mais "bits" que possam descrever a imagem com o intuito de indexação por comparação (distância Euclidiana ou Chi-Square para os floats, Hamming para os bits) na busca de imagens similares. Assim, precisaremos "apenas" de 1GB a 4GB de RAM para montar a matriz ordenada na memória.
#
# Importante ter em mente que a busca é uma comparação one X all (um contra todos), ou seja, uma única imagem buscada será comparada, todas as vezes, com o banco todo. Portanto, não é um caso de agrupamento/cluster como kNN, até porque a busca é sempre relativa à imagem buscada. Também não é uma busca possível de ser feita em banco de dados, pois não há como indexar ANTES de calcular a distância de cada número ou bit.
#
# Algoritmos de agrupamento podem seu úteis caso o BD fique grande demais, mas aí o ideal é um algoritmo de agrupamento simples, um cálculo, por exemplo de "densidade de imagem", e criar n limites (thresholds) de densidade para criar n bancos separados. Aí aplica-se o algoritmo na imagem buscada e determina-se o banco onde esta será buscada. Caso a imagem esteja muito próxima de um threshold, busca-se em dois bancos simultâneos.

# %%
from __future__ import division, print_function, absolute_import

import numpy as np
import matplotlib.pyplot as plt
import tflearn
import glob
import os
from PIL import Image

home = '/home/ivan/Área de Trabalho/ajna/amostras/stamps/'
dest = os.path.join(home, 'resize/')
size = (256, 120)

# %%
3000*365*5
# Out:
# 5475000

# %% [markdown]
# ## Redimensionamento de imagens - rodar somente se necessário

# %%
#for file in glob.glob(os.path.join(home,'*.jpg')):
    im = Image.open(file)
    im2 = im.resize(size, Image.ANTIALIAS)
    im2.save(os.path.join(dest, file[-15:]), "JPEG")

# %% [markdown]
# ## Carrega imagens transformando em matriz

# %%
# %matplotlib inline
from sys import getsizeof

input = size[0]*size[1]
numarquivos = len([name for name in os.listdir(dest) if name.endswith('jpg')])

X = np.ndarray(shape=(numarquivos, input), dtype=np.float32)
print(X.shape)

Xorig = np.ndarray(shape=(numarquivos, size[1], size[0]), dtype=np.float32)

cont = 0
for file in glob.glob(os.path.join(dest,'*.jpg')):
    im = Image.open(file)
    Xorig[cont] = np.asarray(im)
    X[cont] = np.asarray(im).reshape(input)
    cont +=1

print(getsizeof(X))
f, a = plt.subplots(2, 2, figsize=(10, 10))
for i in range(2):
    a[0][i].imshow(np.reshape(X[i], (size[1], size[0])), cmap='gray')
    a[1][i].imshow(np.reshape(Xorig[i], (size[1], size[0])), cmap='gray')
f.show()
plt.draw()
# Out:
# (652, 30720)
# 80117872
# /usr/lib/python3/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# **Normalizar entre 0 e 1 para facilitar aprendizado**

# %%
X = X / 255
X
# Out:
# array([[ 0.22352941,  0.28235295,  0.25882354, ...,  0.23921569,
#          0.12941177,  0.05098039],
#        [ 0.15686275,  0.3882353 ,  0.50980395, ...,  0.07058824,
#          0.36470589,  0.28235295],
#        [ 0.43529412,  0.4509804 ,  0.85882354, ...,  0.03137255,
#          0.05490196,  0.03529412],
#        ...,
#        [ 0.36078432,  0.3137255 ,  0.27450982, ...,  0.12156863,
#          0.13725491,  0.07058824],
#        [ 0.42352942,  0.33725491,  0.63137257, ...,  0.05098039,
#          0.12156863,  0.42745098],
#        [ 0.31764707,  0.43921569,  0.60392159, ...,  0.05490196,
#          0.01176471,  0.02352941]], dtype=float32)

# %% [markdown]
# ## Monta encoder plano (fully connected)

# %%
# Building the encoder
print(input)
print(input*300)
print(300*100)
encoder = tflearn.input_data(shape=[None, input])
encoder = tflearn.fully_connected(encoder, 400)
encoder = tflearn.fully_connected(encoder, 200)
# Building the decoder
decoder = tflearn.fully_connected(encoder, 400)
decoder = tflearn.fully_connected(decoder, input, activation='sigmoid')

# Regression, with mean square error
net = tflearn.regression(decoder, optimizer='adam', learning_rate=0.001,
                         loss='mean_square', metric=None)
model = tflearn.DNN(net, tensorboard_verbose=0)
# Out:
# 30720
# 9216000
# 30000

# %%
print("Total de parâmetros:")
print(input*2+input*300*2+100*300)
# Out:
# Total de parâmetros:
# 18523440

# %%
X.shape
# Out:
# (652, 30720)

# %%
print("Tamanho da representação:")
print(encoder.shape)
# Out:
# Tamanho da representação:
# (?, 200)

# %%
# Training the auto encoder

model.fit(X[:639], X[:639], n_epoch=100, run_id="auto_encoder", batch_size=80)
# Out:
# Training Step: 799  | total loss: 0.00774 | time: 1.583s
# | Adam | epoch: 100 | loss: 0.00774 -- iter: 560/639
# Training Step: 800  | total loss: 0.00766 | time: 1.812s
# | Adam | epoch: 100 | loss: 0.00766 -- iter: 639/639
# --

# %%
# %matplotlib inline
# Encoding X[0] for test
print("\nTest encoding of X[0]:")
# New model, re-using the same session, for weights sharing
encoding_model = tflearn.DNN(encoder, session=model.session)
print(X[0])
print(encoding_model.predict([X[0]]))

# Testing the image reconstruction on new data (test set)
print("\nVisualizing results after being encoded and decoded:")
#testX = tflearn.data_utils.shuffle(testX)[0]
# Applying encode and decode over test set
encode_decode = model.predict(X[0:10])
# Compare original images with their reconstructions
f, a = plt.subplots(2, 10, figsize=(20, 4))
for i in range(10):
    #temp = [[ii, ii] for ii in list(X[i])]
    a[0][i].imshow(np.reshape(X[i], (size[1], size[0])), cmap='gray')
    #temp = [[ii, ii] for ii in list(encode_decode[i])]
    a[1][i].imshow(np.reshape(encode_decode[i], (size[1], size[0])), cmap='gray')
f.show()
plt.draw()
# Out:
# Test encoding of X[0]:
# [ 0.22352941  0.28235295  0.25882354 ...,  0.23921569  0.12941177
#   0.05098039]
# [[4.897933483123779, -1.7184706926345825, 0.6896719932556152, -0.5314728617668152, -2.1172380447387695, -3.497640371322632, -4.854184150695801, -0.8620917201042175, 6.543034076690674, -3.8470911979675293, 4.942697048187256, 1.2323927879333496, -1.4846917390823364, -1.8519268035888672, -1.5312796831130981, -1.8031505346298218, -0.954465389251709, -3.777325391769409, 0.2997204065322876, -15.368456840515137, 0.47658011317253113, 0.7802581191062927, -5.97224235534668, -5.377692699432373, 1.4079005718231201, 0.12082749605178833, -0.3064177930355072, 5.270274639129639, -0.904893159866333, -3.2340362071990967, -1.8712007999420166, -3.0514564514160156, -1.0738955736160278, -0.2446984201669693, -0.7698429822921753, 0.8378614187240601, 5.566705703735352, -1.467760682106018, -0.43396565318107605, -1.9406381845474243, -4.122467517852783, 4.242256164550781, 5.035825252532959, 5.948013782501221, 4.061650276184082, -6.277529716491699, -0.0270549263805151, -3.0954859256744385, 4.141963005065918, -30.13381004333496, 1.8118882179260254, -2.7228922843933105, 2.9802403450012207, -2.540076732635498, -9.605978012084961, 9.720978736877441, -5.316396713256836, 17.04922866821289, 2.2931997776031494, 3.1636250019073486, 2.0920233726501465, -1.318937063217163, -0.8958355188369751, -1.4297157526016235, 0.26774510741233826, -2.7636160850524902, 0.8906628489494324, 0.3578973412513733, -1.0337731838226318, -4.433780670166016, -1.6771312952041626, -6.1398210525512695, -3.3699519634246826, -1.9369202852249146, 0.32441797852516174, 2.7435076236724854, 0.32122424244880676, 4.268751621246338, 0.6547472476959229, 2.5205090045928955, 2.089118480682373, 0.7651119232177734, 6.532646179199219, 7.475503444671631, 1.072531819343567, 9.054192543029785, 6.470298767089844, 6.639507293701172, 0.7396186590194702, -14.687971115112305, -2.913905143737793, 1.9484106302261353, 0.17002999782562256, 1.2502559423446655, 0.03837139531970024, -4.875401020050049, 3.5717129707336426, -3.0833725929260254, -6.023711204528809, -3.280747413635254, -4.312391757965088, 0.2310137301683426, -1.249000906944275, -2.0722813606262207, -7.772310256958008, -4.758598804473877, 1.427689552307129, 2.3040788173675537, -0.053674355149269104, 0.20362786948680878, -0.645933985710144, -8.938822746276855, 6.668094635009766, -2.1568655967712402, 3.3060550689697266, 0.6617407202720642, -1.5166373252868652, 3.892866611480713, 0.042229779064655304, 2.3295061588287354, -0.6477661728858948, -3.20736026763916, -2.177537202835083, -6.128933906555176, 3.8394787311553955, 9.027872085571289, 0.902018666267395, -6.76544189453125, 2.2212281227111816, -0.8304044604301453, 1.0509995222091675, -0.9305570125579834, 2.8299849033355713, -3.7083561420440674, -1.7305415868759155, 0.6489464640617371, 4.086798667907715, -1.8859937191009521, -2.2755911350250244, 4.9629807472229, -3.222015380859375, -1.762762188911438, 32.42892074584961, 2.259192705154419, -8.784953117370605, -7.675259590148926, 3.1165568828582764, -5.820356369018555, -3.6593332290649414, -5.4177727699279785, 5.177877902984619, -0.3054383397102356, 5.010106086730957, -3.175130844116211, 1.6918997764587402, -9.643447875976562, 3.084749937057495, -2.598280429840088, 1.0025858879089355, 1.141494870185852, 0.8980839848518372, -1.0184800624847412, 1.5008231401443481, 0.13929054141044617, -3.2960011959075928, -0.5093075037002563, 1.745061993598938, 0.5236707329750061, 2.854836940765381, -2.937394857406616, 8.588027000427246, 4.685324668884277, 0.4642525315284729, -3.444096326828003, 9.501450538635254, -22.867097854614258, -0.9830265045166016, 1.6470736265182495, -3.8306989669799805, 2.2289936542510986, 5.3776021003723145, 35.60330581665039, 3.360053062438965, 7.8028130531311035, 10.862447738647461, -1.5625276565551758, -2.0289993286132812, 9.658652305603027, 8.784845352172852, 3.1508326530456543, -6.240797519683838, -0.17819081246852875, 4.877396106719971, 0.86118483543396, 1.3247976303100586, 3.2847609519958496, 0.7169726490974426, 5.041557788848877, 0.9183089137077332, ...
#
# Visualizing results after being encoded and decoded:
# /usr/lib/python3/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ## Montar Encoder convolucional

# %%
import tensorflow as tf

inputs_ = tf.placeholder(tf.float32, (None, size[1], size[0], 1), name='inputs')
targets_ = tf.placeholder(tf.float32, (None, size[1], size[0], 1), name='targets')

### Encoder
conv1 = tf.layers.conv2d(inputs_, 32, (3,3), padding='same', activation=tf.nn.relu)
maxpool1 = tf.layers.max_pooling2d(conv1, (2,2), (2,2), padding='same')
conv2 = tf.layers.conv2d(maxpool1, 16, (3,3), padding='same', activation=tf.nn.relu)
maxpool2 = tf.layers.max_pooling2d(conv2, (2,2), (2,2), padding='same')
conv3 = tf.layers.conv2d(maxpool2, 16, (3,3), padding='same', activation=tf.nn.relu)
maxpool3 = tf.layers.max_pooling2d(conv3, (2,2), (2,2), padding='same')
conv31 = tf.layers.conv2d(maxpool3, 8, (3,3), padding='same', activation=tf.nn.relu)
maxpool31 = tf.layers.max_pooling2d(conv31, (2,2), (2,2), padding='same')
conv32 = tf.layers.conv2d(maxpool31, 8, (3,3), padding='same', activation=tf.nn.relu)
encoded = tf.layers.max_pooling2d(conv32, (2,2), (2,2), padding='same')

### Decoder
upsample00 = tf.image.resize_nearest_neighbor(encoded, (int(size[1]/16),int(size[0]/16)))
conv34 = tf.layers.conv2d(upsample00, 8, (3,3), padding='same', activation=tf.nn.relu)
upsample0 = tf.image.resize_nearest_neighbor(encoded, (int(size[1]/8),int(size[0]/8)))
conv34 = tf.layers.conv2d(upsample0, 8, (3,3), padding='same', activation=tf.nn.relu)
upsample1 = tf.image.resize_nearest_neighbor(encoded, (int(size[1]/4),int(size[0]/4)))
conv4 = tf.layers.conv2d(upsample1, 8, (3,3), padding='same', activation=tf.nn.relu)
upsample2 = tf.image.resize_nearest_neighbor(conv4, (int(size[1]/2),int(size[0]/2)))
conv5 = tf.layers.conv2d(upsample2, 8, (3,3), padding='same', activation=tf.nn.relu)
upsample3 = tf.image.resize_nearest_neighbor(conv5, (int(size[1]),int(size[0])))
conv6 = tf.layers.conv2d(upsample3, 16, (3,3), padding='same', activation=tf.nn.relu)
logits = tf.layers.conv2d(conv6, 1, (3,3), padding='same', activation=None)

decoded = tf.nn.sigmoid(logits, name='decoded')

loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets_, logits=logits)
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(0.001).minimize(cost)

# %%
maxpool1.shape
# Out:
# TensorShape([Dimension(None), Dimension(60), Dimension(128), Dimension(32)])

# %%
maxpool2.shape
# Out:
# TensorShape([Dimension(None), Dimension(30), Dimension(64), Dimension(16)])

# %%
maxpool3.shape
# Out:
# TensorShape([Dimension(None), Dimension(15), Dimension(32), Dimension(16)])

# %%
maxpool31.shape
# Out:
# TensorShape([Dimension(None), Dimension(8), Dimension(16), Dimension(8)])

# %%
encoded.shape
# Out:
# TensorShape([Dimension(None), Dimension(4), Dimension(8), Dimension(8)])

# %% [markdown]
#  ## Conforme abaixo, a rede convolucional usa muito menos pesos, mas é mais difícil conseguir uma representação tão condensada
#
# Por outro lado, a rede convolucional tende a ter maior invariância quanto à posição dos objetos. Por exemplo, imagine-se um contêiner vazio, um contêiner com apenas um pallet à esquerda e  um contêiner com apenas um pallet à direita.
#
# Para a rede plana, a tendência é que ela considere o vazio mais diferente do que os dois com apenas um pallet. Já na rede convolucional, espera-se que ela "diga" que os contêineres com apenas um pallet cada são mais parecidos entre si.
#
# Assim, nas imagens A, B, C, D e E abaixo (caixa pequena à esquerda, caixa grande à esquerda, caixa pequena à direita, caixa grande à direita, vazio), o ideal é que uma procura pela imagem "A" retornasse (A, C, B, D, E ou A, C, E, D, D). Entretanto numa busca ou comparação plana/sequencial ou qualquer algoritmo de comparação de pontos da imagem o esperado seria A, B, E, C, D. As imagens F e G também estão apenas "espelhadas", mas a tendência é que algoritmos de comparação de imagens a considerem mais diferentes entre si do que entre elas e um vazio. Vamos carregar estas imagens e testar nossos encoders.

# %% [markdown]
#  ## A ![Imagem A](imgnotebook/exemplocaixa1.png)
#  ## B ![Imagem B](imgnotebook/exemplocaixa2.png)
#  ## C ![Imagem C](imgnotebook/exemplocaixa1espelhado.png)
#  ## D ![Imagem D](imgnotebook/exemplocaixa2espelhado.png)
#  ## E ![Imagem E](imgnotebook/exemplovazio.png)
#  ## F ![Imagem F](imgnotebook/exemplocirculo.png)
#  ## G ![Imagem G](imgnotebook/exemplocirculoespelhado.png)

# %%
print("Tamanho do encoder")
print(encoded.shape[1]*encoded.shape[2]*encoded.shape[3])
# Out:
# Tamanho do encoder
# 256

# %%
sess = tf.Session()
epochs = 100
batch_size = 217
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(X.shape[0]//batch_size):
        batch = X[ii:(ii+1)*batch_size]
        imgs = batch[0].reshape((-1, size[1], size[0], 1))
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: imgs,
                                                         targets_: imgs})
        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epoch: 1/100... Training loss: 0.6941
# Epoch: 1/100... Training loss: 0.6919
# Epoch: 1/100... Training loss: 0.6920
# Epoch: 2/100... Training loss: 0.6913
# Epoch: 2/100... Training loss: 0.6874
# Epoch: 2/100... Training loss: 0.6891
# Epoch: 3/100... Training loss: 0.6875
# Epoch: 3/100... Training loss: 0.6783
# Epoch: 3/100... Training loss: 0.6824
# Epoch: 4/100... Training loss: 0.6782
# Epoch: 4/100... Training loss: 0.6610
# Epoch: 4/100... Training loss: 0.6692
# Epoch: 5/100... Training loss: 0.6624
# Epoch: 5/100... Training loss: 0.6313
# Epoch: 5/100... Training loss: 0.6504
# Epoch: 6/100... Training loss: 0.6359
# Epoch: 6/100... Training loss: 0.5904
# Epoch: 6/100... Training loss: 0.6310
# Epoch: 7/100... Training loss: 0.5894
# Epoch: 7/100... Training loss: 0.5491
# Epoch: 7/100... Training loss: 0.6116
# Epoch: 8/100... Training loss: 0.5223
# Epoch: 8/100... Training loss: 0.5096
# Epoch: 8/100... Training loss: 0.6130
# Epoch: 9/100... Training loss: 0.4597
# Epoch: 9/100... Training loss: 0.4678
# Epoch: 9/100... Training loss: 0.6288
# Epoch: 10/100... Training loss: 0.4171
# Epoch: 10/100... Training loss: 0.4305
# Epoch: 10/100... Training loss: 0.6250
# Epoch: 11/100... Training loss: 0.3892
# Epoch: 11/100... Training loss: 0.3763
# Epoch: 11/100... Training loss: 0.6209
# Epoch: 12/100... Training loss: 0.3775
# Epoch: 12/100... Training loss: 0.3386
# Epoch: 12/100... Training loss: 0.6170
# Epoch: 13/100... Training loss: 0.3670
# Epoch: 13/100... Training loss: 0.3096
# Epoch: 13/100... Training loss: 0.6230
# Epoch: 14/100... Training loss: 0.3537
# Epoch: 14/100... Training loss: 0.2942
# Epoch: 14/100... Training loss: 0.6259
# Epoch: 15/100... Training loss: 0.3466
# Epoch: 15/100... Training loss: 0.2820
# Epoch: 15/100... Training loss: 0.6257
# Epoch: 16/100... Training loss: 0.3435
# Epoch: 16/100... Training loss: 0.2816
# Epoch: 16/100... Training loss: 0.6284
# Epoch: 17/100... Training loss: 0.3474
# Epoch: 17/100... Training loss: 0.2780
# Epoch: 17/100... Training loss: 0.6171
# Epoch: 18/100... Training loss: 0.3460
# Epoch: 18/100... Training loss: 0.2757
# Epoch: 18/100... Training loss: 0.6427
# Epoch: 19/100... Training loss: 0.3393
# Epoch: 19/100... Training loss: 0.2727
# Epoch: 19/100... Training loss: 0.6174
# Epoch: 20/100... Training loss: 0.3510
# Epoch: 20/100... Training loss: 0.2711
# Epoch: 20/100... Training loss: 0.6176
# Epoch: 21/100... Training loss: 0.3381
# Epoch: 21/100... Training loss: 0.2714
# Epoch: 21/100... Training loss: 0.6061
# Epoch: 22/100... Training loss: 0.3426
# Epoch: 22/100... Training loss: 0.2700
# Epoch: 22/100... Training loss: 0.6065
# Epoch: 23/100... Training loss: 0.3376
# Epoch: 23/100... Training loss: 0.2695
# Epoch: 23/100... Training loss: 0.6136
# Epoch: 24/100... Training loss: 0.3353
# Epoch: 24/100... Training loss: 0.2675
# Epoch: 24/100... Training loss: 0.6081
# Epoch: 25/100... Training loss: 0.3380
# Epoch: 25/100... Training loss: 0.2667
# Epoch: 25/100... Training loss: 0.6058
# Epoch: 26/100... Training loss: 0.3347
# Epoch: 26/100... Training loss: 0.2672
# Epoch: 26/100... Training loss: 0.6058
# Epoch: 27/100... Training loss: 0.3351
# Epoch: 27/100... Training loss: 0.2660
# Epoch: 27/100... Training loss: 0.6050
# Epoch: 28/100... Training loss: 0.3352
# Epoch: 28/100... Training loss: 0.2656
# Epoch: 28/100... Training loss: 0.6064
# Epoch: 29/100... Training loss: 0.3333
# Epoch: 29/100... Training loss: 0.2650
# Epoch: 29/100... Training loss: 0.6040
# Epoch: 30/100... Training loss: 0.3341
# Epoch: 30/100... Training loss: 0.2646
# Epoch: 30/100... Training loss: 0.6042
# Epoch: 31/100... Training loss: 0.3321
# Epoch: 31/100... Training loss: 0.2644
# Epoch: 31/100... Training loss: 0.6039
# Epoch: 32/100... Training loss: 0.3322
# Epoch: 32/100... Training loss: 0.2641
# Epoch: 32/100... Training loss: 0.6029
# Epoch: 33/100... Training loss: 0.3316
# Epoch: 33/100... Training loss: 0.2639
# Epoch: 33/100... Training loss: 0.6041
# Epoch: 34/100... Training loss: 0.3309
# Epoch: 34/100... Training loss: 0.2633
# Epoch: 34/100... Training loss: 0.6025
# Epoch: 35/100... Training loss: 0.3314
# Epoch: 35/100... Training loss: 0.2630
# Epoch: 35/100... Training loss: 0.6041
# Epoch: 36/100... Training loss: 0.3300
# Epoch: 36/100... Training loss: 0.2626
# Epoch: 36/100... Training loss: 0.6019
# Epoch: 37/100... Training loss: 0.3307
# Epoch: 37/100... Training loss: 0.2623
# Epoch: 37/100... Training loss: 0.6031
# Epoch: 38/100... Training loss: 0.3295
# Epoch: 38/100... Training loss: 0.2621
# Epoch: 38/100... Training loss: 0.6012
# Epoch: 39/100... Training loss: 0.3299
# Epoch: 39/100... Training loss: 0.2619
# Epoch: 39/100... Training loss: 0.6021
# Epoch: 40/100... Training loss: 0.3290
# Epoch: 40/100... Training loss: 0.2616
# Epoch: 40/100... Training loss: 0.6009
# Epoch: 41/100... Training loss: 0.3291
# Epoch: 41/100... Training loss: 0.2615
# Epoch: 41/100... Training loss: 0.6019
# Epoch: 42/100... Training loss: 0.3283
# Epoch: 42/100... Training loss: 0.2612
# Epoch: 42/100... Training loss: 0.6006
# Epoch: 43/100... Training loss: 0.3282
# Epoch: 43/100... Training loss: 0.2611
# Epoch: 43/100... Training loss: 0.6021
# Epoch: 44/100... Training loss: 0.3277
# Epoch: 44/100... Training loss: 0.2610
# Epoch: 44/100... Training loss: 0.6007
# Epoch: 45/100... Training loss: 0.3274
# Epoch: 45/100... Training loss: 0.2612
# Epoch: 45/100... Training loss: 0.6034
# Epoch: 46/100... Training loss: 0.3272
# Epoch: 46/100... Training loss: 0.2611
# Epoch: 46/100... Training loss: 0.6019
# Epoch: 47/100... Training loss: 0.3269
# Epoch: 47/100... Training loss: 0.2617
# Epoch: 47/100... Training loss: 0.6077
# Epoch: 48/100... Training loss: 0.3267
# Epoch: 48/100... Training loss: 0.2615
# Epoch: 48/100... Training loss: 0.6058
# Epoch: 49/100... Training loss: 0.3273
# Epoch: 49/100... Training loss: 0.2626
# Epoch: 49/100... Training loss: 0.6148
# Epoch: 50/100... Training loss: 0.3260
# Epoch: 50/100... Training loss: 0.2611
# Epoch: 50/100... Training loss: 0.6082
# Epoch: 51/100... Training loss: 0.3300
# Epoch: 51/100... Training loss: 0.2615
# Epoch: 51/100... Training loss: 0.6117
# Epoch: 52/100... Training loss: 0.3261
# Epoch: 52/100... Training loss: 0.2604
# Epoch: 52/100... Training loss: 0.6004
# Epoch: 53/100... Training loss: 0.3303
# Epoch: 53/100... Training loss: 0.2602
# Epoch: 53/100... Training loss: 0.5999
# Epoch: 54/100... Training loss: 0.3253
# Epoch: 54/100... Training loss: 0.2607
# Epoch: 54/100... Training loss: 0.5992
# Epoch: 55/100... Training loss: 0.3262
# Epoch: 55/100... Training loss: 0.2599
# Epoch: 55/100... Training loss: 0.5987
# Epoch: 56/100... Training loss: 0.3251
# Epoch: 56/100... Training loss: 0.2603
# Epoch: 56/100... Training loss: 0.6009
# Epoch: 57/100... Training loss: 0.3247
# Epoch: 57/100... Training loss: 0.2599
# Epoch: 57/100... Training loss: 0.5994
# Epoch: 58/100... Training loss: 0.3252
# Epoch: 58/100... Training loss: 0.2599
# Epoch: 58/100... Training loss: 0.6018
# Epoch: 59/100... Training loss: 0.3242
# Epoch: 59/100... Training loss: 0.2595
# Epoch: 59/100... Training loss: 0.5993
# Epoch: 60/100... Training loss: 0.3252
# Epoch: 60/100... Training loss: 0.2595
# Epoch: 60/100... Training loss: 0.6009
# Epoch: 61/100... Training loss: 0.3239
# Epoch: 61/100... Training loss: 0.2591
# Epoch: 61/100... Training loss: 0.5982
# Epoch: 62/100... Training loss: 0.3249
# Epoch: 62/100... Training loss: 0.2593
# Epoch: 62/100... Training loss: 0.5988
# Epoch: 63/100... Training loss: 0.3236
# Epoch: 63/100... Training loss: 0.2589
# Epoch: 63/100... Training loss: 0.5974
# Epoch: 64/100... Training loss: 0.3240
# Epoch: 64/100... Training loss: 0.2589
# Epoch: 64/100... Training loss: 0.5981
# Epoch: 65/100... Training loss: 0.3232
# Epoch: 65/100... Training loss: 0.2586
# Epoch: 65/100... Training loss: 0.5972
# Epoch: 66/100... Training loss: 0.3235
# Epoch: 66/100... Training loss: 0.2584
# Epoch: 66/100... Training loss: 0.5977
# Epoch: 67/100... Training loss: 0.3230
# Epoch: 67/100... Training loss: 0.2581
# Epoch: 67/100... Training loss: 0.5970
# Epoch: 68/100... Training loss: 0.3230
# Epoch: 68/100... Training loss: 0.2583
# Epoch: 68/100... Training loss: 0.5977
# Epoch: 69/100... Training loss: 0.3227
# Epoch: 69/100... Training loss: 0.2580
# Epoch: 69/100... Training loss: 0.5970
# Epoch: 70/100... Training loss: 0.3224
# Epoch: 70/100... Training loss: 0.2583
# Epoch: 70/100... Training loss: 0.5983
# Epoch: 71/100... Training loss: 0.3224
# Epoch: 71/100... Training loss: 0.2577
# Epoch: 71/100... Training loss: 0.5980
# Epoch: 72/100... Training loss: 0.3220
# Epoch: 72/100... Training loss: 0.2587
# Epoch: 72/100... Training loss: 0.6008
# Epoch: 73/100... Training loss: 0.3223
# Epoch: 73/100... Training loss: 0.2584
# Epoch: 73/100... Training loss: 0.6003
# Epoch: 74/100... Training loss: 0.3220
# Epoch: 74/100... Training loss: 0.2598
# Epoch: 74/100... Training loss: 0.6052
# Epoch: 75/100... Training loss: 0.3218
# Epoch: 75/100... Training loss: 0.2583
# Epoch: 75/100... Training loss: 0.6047
# Epoch: 76/100... Training loss: 0.3231
# Epoch: 76/100... Training loss: 0.2597
# Epoch: 76/100... Training loss: 0.6087
# Epoch: 77/100... Training loss: 0.3219
# Epoch: 77/100... Training loss: 0.2574
# Epoch: 77/100... Training loss: 0.6024
# Epoch: 78/100... Training loss: 0.3260
# Epoch: 78/100... Training loss: 0.2574
# Epoch: 78/100... Training loss: 0.6011
# Epoch: 79/100... Training loss: 0.3222
# Epoch: 79/100... Training loss: 0.2576
# Epoch: 79/100... Training loss: 0.5957
# Epoch: 80/100... Training loss: 0.3242
# Epoch: 80/100... Training loss: 0.2573
# Epoch: 80/100... Training loss: 0.5954
# Epoch: 81/100... Training loss: 0.3213
# Epoch: 81/100... Training loss: 0.2580
# Epoch: 81/100... Training loss: 0.5967
# Epoch: 82/100... Training loss: 0.3212
# Epoch: 82/100... Training loss: 0.2570
# Epoch: 82/100... Training loss: 0.5970
# Epoch: 83/100... Training loss: 0.3212
# Epoch: 83/100... Training loss: 0.2573
# Epoch: 83/100... Training loss: 0.5973
# Epoch: 84/100... Training loss: 0.3208
# Epoch: 84/100... Training loss: 0.2563
# Epoch: 84/100... Training loss: 0.5961
# Epoch: 85/100... Training loss: 0.3217
# Epoch: 85/100... Training loss: 0.2562
# Epoch: 85/100... Training loss: 0.5964
# Epoch: 86/100... Training loss: 0.3205
# Epoch: 86/100... Training loss: 0.2559
# Epoch: 86/100... Training loss: 0.5952
# Epoch: 87/100... Training loss: 0.3209
# Epoch: 87/100... Training loss: 0.2557
# Epoch: 87/100... Training loss: 0.5951
# Epoch: 88/100... Training loss: 0.3199
# Epoch: 88/100... Training loss: 0.2556
# Epoch: 88/100... Training loss: 0.5950
# Epoch: 89/100... Training loss: 0.3198
# Epoch: 89/100... Training loss: 0.2554
# Epoch: 89/100... Training loss: 0.5947
# Epoch: 90/100... Training loss: 0.3194
# Epoch: 90/100... Training loss: 0.2551
# Epoch: 90/100... Training loss: 0.5946
# Epoch: 91/100... Training loss: 0.3191
# Epoch: 91/100... Training loss: 0.2550
# Epoch: 91/100... Training loss: 0.5945
# Epoch: 92/100... Training loss: 0.3188
# Epoch: 92/100... Training loss: 0.2548
# Epoch: 92/100... Training loss: 0.5943
# Epoch: 93/100... Training loss: 0.3187
# Epoch: 93/100... Training loss: 0.2546
# Epoch: 93/100... Training loss: 0.5944
# Epoch: 94/100... Training loss: 0.3184
# Epoch: 94/100... Training loss: 0.2544
# Epoch: 94/100... Training loss: 0.5941
# Epoch: 95/100... Training loss: 0.3183
# Epoch: 95/100... Training loss: 0.2543
# Epoch: 95/100... Training loss: 0.5941
# Epoch: 96/100... Training loss: 0.3180
# Epoch: 96/100... Training loss: 0.2541
# Epoch: 96/100... Training loss: 0.5939
# Epoch: 97/100... Training loss: 0.3177
# Epoch: 97/100... Training loss: 0.2541
# Epoch: 97/100... Training loss: 0.5938
# Epoch: 98/100... Training loss: 0.3175
# Epoch: 98/100... Training loss: 0.2539
# Epoch: 98/100... Training loss: 0.5937
# Epoch: 99/100... Training loss: 0.3174
# Epoch: 99/100... Training loss: 0.2540
# Epoch: 99/100... Training loss: 0.5935
# Epoch: 100/100... Training loss: 0.3173
# Epoch: 100/100... Training loss: 0.2537
# Epoch: 100/100... Training loss: 0.5934

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = X[:10]
reconstructed = sess.run(decoded, feed_dict={inputs_: in_imgs.reshape((10, size[1], size[0], 1))})

for images, row in zip([in_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((size[1], size[0])), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
fig.tight_layout(pad=0.1)

# %% [markdown]
#  ## Usar informações do núcleo dos encoders para testar indexação

# %% [markdown]
#  ## Somente as duas células abaixo para a rede convolucional

# %%
#Caso não seja possível carregar imagens na memória, será necessário loop anterior para carregar imagens em lote
def gerarEncodedConv(session, encoder, Xtotal, batch_size = 64):
    compressed = np.empty((0, 256))
    for r in range(0, Xtotal.shape[0] // batch_size):
        ind1 = r*batch_size
        ind2 = ind1+batch_size
        if  ind2 > Xtotal.shape[0]:
            ind2 = Xtotal.shape[0] - 1
        Xbatch = Xtotal[ind1:ind2]
        compressedbatch = sess.run([encoder], feed_dict={inputs_: Xbatch.reshape((-1, size[1], size[0], 1))})
        compressed = np.concatenate((compressed, np.array(compressedbatch).reshape(-1, 256)), axis=0)
    return compressed
    
compressed = gerarEncodedConv(sess, encoded, X)
print(compressed)
print(compressed.shape)
print(compressed.nbytes) # Memória que será usada
# Out:
# [[ 0.          0.          0.23429054 ...,  0.          0.          0.93378377]
#  [ 0.76334375  0.          0.20620519 ...,  0.04860488  0.          1.06468618]
#  [ 0.14602692  0.          0.11857118 ...,  0.          0.          0.0600929 ]
#  ...,
#  [ 0.47598445  0.          0.08701094 ...,  0.          0.          0.60259318]
#  [ 0.          0.          0.30167446 ...,  0.          0.          0.82165283]
#  [ 0.3960354   0.          0.08694166 ...,  0.          0.          0.44375131]]
# (640, 256)
# 1310720

# %%
imgSearch = X[30].reshape((-1, size[1], size[0], 1))
compressedSearch = np.array(sess.run([encoded], feed_dict={inputs_: imgSearch})).reshape(-1, 256)

# %% [markdown]
#  ## Somente as duas células abaixo para a rede plana

# %%
compressed = encoding_model.predict(X)
print(compressed[:1])
# Out:
# [[4.897931098937988, -1.7184385061264038, 0.6896643042564392, -0.5314891934394836, -2.1172616481781006, -3.4976375102996826, -4.854167938232422, -0.862091600894928, 6.543038845062256, -3.847111701965332, 4.942712783813477, 1.23241126537323, -1.484719157218933, -1.8519151210784912, -1.531277060508728, -1.803162932395935, -0.9544658660888672, -3.777315378189087, 0.2997475564479828, -15.36844539642334, 0.47659188508987427, 0.7802829742431641, -5.972211837768555, -5.377694129943848, 1.4078704118728638, 0.12082909792661667, -0.30642250180244446, 5.270263671875, -0.9048789739608765, -3.2340383529663086, -1.8711689710617065, -3.051447629928589, -1.0738706588745117, -0.2447061538696289, -0.7698476314544678, 0.8378998041152954, 5.566689968109131, -1.4677616357803345, -0.433958500623703, -1.9406193494796753, -4.122460842132568, 4.242218971252441, 5.035819053649902, 5.947988986968994, 4.061657905578613, -6.277484893798828, -0.027040231972932816, -3.0954673290252686, 4.141941547393799, -30.133806228637695, 1.8119001388549805, -2.7228925228118896, 2.980259418487549, -2.5400490760803223, -9.606024742126465, 9.720955848693848, -5.316396713256836, 17.04917335510254, 2.2931883335113525, 3.16363525390625, 2.092026710510254, -1.3189488649368286, -0.8958197832107544, -1.4297064542770386, 0.26773732900619507, -2.7635881900787354, 0.890670657157898, 0.357916921377182, -1.0337988138198853, -4.43380880355835, -1.677121639251709, -6.13984489440918, -3.369943618774414, -1.936894416809082, 0.32442906498908997, 2.743511199951172, 0.32124030590057373, 4.268741607666016, 0.6547214984893799, 2.5205342769622803, 2.0891261100769043, 0.7650644779205322, 6.532646656036377, 7.475499629974365, 1.0725157260894775, 9.054211616516113, 6.470318794250488, 6.639492988586426, 0.739639401435852, -14.687946319580078, -2.9139044284820557, 1.9484249353408813, 0.17004802823066711, 1.25026273727417, 0.03838975727558136, -4.875392436981201, 3.5717103481292725, -3.0833988189697266, -6.023721694946289, -3.2807552814483643, -4.312407493591309, 0.2309914082288742, -1.2489960193634033, -2.0722155570983887, -7.772319793701172, -4.758578777313232, 1.4277104139328003, 2.304053783416748, -0.053687527775764465, 0.2036377340555191, -0.645950198173523, -8.938833236694336, 6.668061256408691, -2.156843423843384, 3.30604887008667, 0.6617137789726257, -1.516628623008728, 3.8928794860839844, 0.04221068322658539, 2.3294830322265625, -0.6477556228637695, -3.2073659896850586, -2.1775455474853516, -6.128902912139893, 3.8394935131073, 9.027892112731934, 0.9020121693611145, -6.765456199645996, 2.2212278842926025, -0.8304140567779541, 1.0509705543518066, -0.9305452108383179, 2.830002546310425, -3.7083728313446045, -1.7305494546890259, 0.6489364504814148, 4.086778163909912, -1.885984182357788, -2.2755844593048096, 4.962981700897217, -3.2220304012298584, -1.7627679109573364, 32.42893981933594, 2.2592175006866455, -8.784934043884277, -7.675275802612305, 3.116546869277954, -5.820359706878662, -3.6593172550201416, -5.417757987976074, 5.177884101867676, -0.3054792284965515, 5.010091781616211, -3.175097942352295, 1.6918671131134033, -9.643476486206055, 3.0847129821777344, -2.598289728164673, 1.0026004314422607, 1.1415150165557861, 0.8980467319488525, -1.0184781551361084, 1.5008018016815186, 0.13927224278450012, -3.2959988117218018, -0.5093002915382385, 1.7450768947601318, 0.5236372947692871, 2.8548357486724854, -2.93740177154541, 8.588032722473145, 4.685349941253662, 0.4642632007598877, -3.4440739154815674, 9.501463890075684, -22.8670654296875, -0.9830278158187866, 1.647072672843933, -3.8307130336761475, 2.229012966156006, 5.3776092529296875, 35.603309631347656, 3.360051393508911, 7.802823066711426, 10.862462997436523, -1.5625195503234863, -2.029006242752075, 9.658659934997559, 8.78487777709961, 3.1508326530456543, -6.240774154663086, -0.1782103180885315, 4.877389430999756, 0.861146092414856, 1.3247780799865723, 3.2847483158111572, 0.7169488668441772, 5.041592597961426, 0.9182720184326172, 0.741389513015747 ...

# %%
imgSearch = X[50]
compressedSearch = encoding_model.predict([imgSearch])

# %% [markdown]
#  ## Testando indexação, passo a passo...

# %%
Y2 = np.array(compressedSearch, dtype=np.float32)
print(Y2.nbytes) #memória que será usada por imagem buscada
# Out:
# 1024

# %%
X2 = np.array(compressed, dtype=np.float32)
print(X2.shape[0])
print(X2.nbytes*(1000000/X2.shape[0])/1000000) #memória em MB que será usada na lista de imagens para 1 milhão de imagens
# Out:
# 640
# 1024.0

# %%
Delta = X2 - Y2
Delta
# Out:
# array([[-0.72688574,  0.        , -0.00932252, ..., -0.00307127,
#          0.        ,  0.01256031],
#        [ 0.03645802,  0.        , -0.03740788, ...,  0.04553361,
#          0.        ,  0.14346272],
#        [-0.58085883,  0.        , -0.12504187, ..., -0.00307127,
#          0.        , -0.8611306 ],
#        ...,
#        [-0.25090128,  0.        , -0.15660211, ..., -0.00307127,
#          0.        , -0.31863028],
#        [-0.72688574,  0.        ,  0.05806139, ..., -0.00307127,
#          0.        , -0.09957063],
#        [-0.33085033,  0.        , -0.1566714 , ..., -0.00307127,
#          0.        , -0.47747216]], dtype=float32)

# %%
sqrtDistance = np.sqrt(np.square(Delta))
sqrtDistance
# Out:
# array([[ 0.72688574,  0.        ,  0.00932252, ...,  0.00307127,
#          0.        ,  0.01256031],
#        [ 0.03645802,  0.        ,  0.03740788, ...,  0.04553361,
#          0.        ,  0.14346272],
#        [ 0.58085883,  0.        ,  0.12504187, ...,  0.00307127,
#          0.        ,  0.8611306 ],
#        ...,
#        [ 0.25090128,  0.        ,  0.15660211, ...,  0.00307127,
#          0.        ,  0.31863028],
#        [ 0.72688574,  0.        ,  0.05806139, ...,  0.00307127,
#          0.        ,  0.09957063],
#        [ 0.33085033,  0.        ,  0.1566714 , ...,  0.00307127,
#          0.        ,  0.47747216]], dtype=float32)

# %%
sumDistance = sqrtDistance.sum(axis=1)
sumDistance
# Out:
# array([  2.88644238e+01,   9.16363144e+00,   7.09222107e+01,
#          6.68119583e+01,   1.19145546e+01,   4.16623344e+01,
#          1.50691671e+01,   3.09733620e+01,   3.18021488e+01,
#          1.64017677e+01,   1.73527737e+01,   1.69550858e+01,
#          6.16053925e+01,   5.73292923e+01,   1.58586578e+01,
#          5.96109123e+01,   1.31799374e+01,   7.51981506e+01,
#          2.22278099e+01,   3.16671448e+01,   7.36105347e+01,
#          7.30301743e+01,   1.57482319e+01,   1.83711681e+01,
#          4.40484695e+01,   1.58768749e+01,   2.73243256e+01,
#          4.24033775e+01,   2.34116631e+01,   1.72520370e+01,
#          1.95512548e-05,   2.26249046e+01,   3.24627228e+01,
#          2.97645149e+01,   3.01576653e+01,   3.11773567e+01,
#          1.73977051e+01,   2.71658764e+01,   3.00482044e+01,
#          3.67112770e+01,   3.11120033e+01,   7.23209076e+01,
#          1.68859863e+01,   3.16500206e+01,   3.26360474e+01,
#          3.04127617e+01,   3.34297562e+01,   6.75263367e+01,
#          1.52466221e+01,   2.58430119e+01,   2.95655441e+01,
#          7.12307587e+01,   3.24080734e+01,   3.46133728e+01,
#          3.10006313e+01,   3.02438221e+01,   2.10997849e+01,
#          2.33620739e+01,   7.68144226e+01,   2.95637627e+01,
#          6.74334259e+01,   4.83448410e+01,   2.35968018e+01,
#          3.50657272e+01,   1.84054985e+01,   1.70992088e+01,
#          1.49106350e+01,   4.57561798e+01,   1.88261414e+01,
#          2.55238609e+01,   7.37145233e+01,   2.95420456e+01,
#          1.61701069e+01,   3.54760857e+01,   7.32284698e+01,
#          1.61540012e+01,   4.77181549e+01,   3.96728401e+01,
#          3.28206596e+01,   3.04803524e+01,   1.24977493e+01,
#          2.64620438e+01,   1.39312840e+01,   1.41982784e+01,
#          3.50177689e+01,   1.43061352e+01,   4.20746689e+01,
#          2.47002563e+01,   4.78281708e+01,   3.39431343e+01,
#          1.70366402e+01,   7.46919174e+01,   3.36573563e+01,
#          3.36175079e+01,   2.06071873e+01,   1.89472580e+01,
#          3.21997833e+01,   3.00139618e+01,   2.35425186e+01,
#          3.34581909e+01,   3.33418312e+01,   7.19954376e+01,
#          2.08271370e+01,   3.54250870e+01,   2.97645893e+01,
#          7.24248199e+01,   1.65926418e+01,   4.69667130e+01,
#          1.43074884e+01,   3.15201397e+01,   3.15147533e+01,
#          1.94794426e+01,   1.62772369e+01,   1.36190510e+01,
#          7.39638596e+01,   4.71373672e+01,   1.44792414e+01,
#          1.46079178e+01,   3.34576797e+01,   3.33661346e+01,
#          7.31375122e+01,   3.56226082e+01,   7.10723724e+01,
#          3.47858810e+01,   1.21683044e+01,   3.80481720e+01,
#          2.75903549e+01,   4.99887085e+01,   1.97932930e+01,
#          1.79192619e+01,   2.64402847e+01,   3.57458267e+01,
#          1.26229868e+01,   2.25123730e+01,   3.24204102e+01,
#          1.45489054e+01,   2.94204865e+01,   7.29257660e+01,
#          2.93797874e+01,   3.36213531e+01,   3.23331070e+01,
#          5.49112396e+01,   3.33327637e+01,   7.51014938e+01,
#          3.41295319e+01,   3.54775963e+01,   3.02712822e+01,
#          1.70646973e+01,   3.07072887e+01,   1.76909847e+01,
#          1.56677494e+01,   3.14477882e+01,   4.30139618e+01,
#          7.72364731e+01,   7.32891083e+01,   3.34452362e+01,
#          1.41759720e+01,   5.67046661e+01,   8.08361053e+01,
#          4.87768517e+01,   1.75721073e+01,   3.45443916e+01,
#          2.61583843e+01,   3.28074341e+01,   1.75921326e+01,
#          1.53415890e+01,   1.65591526e+01,   2.54679012e+01,
#          1.54756861e+01,   2.53408546e+01,   1.72580261e+01,
#          6.70606842e+01,   2.45588226e+01,   4.19772797e+01,
#          1.81414871e+01,   1.49177675e+01,   3.56551208e+01,
#          2.80965652e+01,   3.44031067e+01,   2.16592636e+01,
#          1.35460358e+01,   3.62870216e+01,   3.27721710e+01,
#          1.81392002e+01,   3.45759048e+01,   2.57385063e+01,
#          7.43592529e+01,   2.46590729e+01,   7.24698105e+01,
#          1.57483377e+01,   1.68190899e+01,   2.14552917e+01,
#          3.13746376e+01,   7.94718323e+01,   3.14784679e+01,
#          1.97946014e+01,   1.70176411e+01,   3.66317825e+01,
#          1.41590433e+01,   1.52376375e+01,   2.89013481e+01,
#          3.32576942e+01,   2.61943245e+01,   1.82564087e+01,
#          7.52426453e+01,   1.78418694e+01,   1.91176910e+01,
#          3.37447548e+01,   1.03604183e+01,   3.65746078e+01,
#          4.11852951e+01,   6.64461670e+01,   7.10419922e+01,
#          1.61757565e+01,   7.43651352e+01,   3.19969006e+01,
#          2.56412849e+01,   1.88374329e+01,   2.97828178e+01,
#          1.57350483e+01,   3.10634193e+01,   2.29652843e+01,
#          6.52083893e+01,   3.19029312e+01,   1.20260592e+01,
#          1.48562222e+01,   7.81493378e+01,   1.35830650e+01,
#          6.58076477e+01,   7.18601532e+01,   3.35265961e+01,
#          2.27332935e+01,   3.11408443e+01,   1.86812935e+01,
#          7.21355286e+01,   2.81211147e+01,   4.11535988e+01,
#          3.41850967e+01,   2.61997070e+01,   3.39432755e+01,
#          6.98232422e+01,   1.65212574e+01,   4.64743309e+01,
#          1.81624641e+01,   1.64093781e+01,   2.71680946e+01,
#          2.10407028e+01,   4.76237717e+01,   2.95618896e+01,
#          7.38700714e+01,   2.38061657e+01,   2.93959179e+01,
#          2.21686916e+01,   3.23202744e+01,   5.23242416e+01,
#          3.06581230e+01,   7.47734833e+01,   2.44640350e+01,
#          3.48492279e+01,   7.13658600e+01,   3.45656166e+01,
#          1.64706821e+01,   4.58108749e+01,   1.24325628e+01,
#          7.02272415e+01,   4.50015373e+01,   7.53433075e+01,
#          1.82988319e+01,   3.22820511e+01,   4.78138885e+01,
#          2.04839516e+01,   1.64548092e+01,   1.73338127e+01,
#          3.05002842e+01,   3.13802414e+01,   7.76151505e+01,
#          3.25364227e+01,   3.08788490e+01,   1.50771923e+01,
#          1.55762739e+01,   1.48208103e+01,   7.49695282e+01,
#          3.45508537e+01,   1.68678017e+01,   3.52513199e+01,
#          1.65803413e+01,   7.55442047e+01,   4.74065514e+01,
#          6.33162079e+01,   1.69773197e+01,   3.80940437e+01,
#          3.17654800e+01,   3.52847900e+01,   7.95031281e+01,
#          3.61092987e+01,   3.10581722e+01,   7.35648193e+01,
#          3.61885681e+01,   6.47523651e+01,   1.45673466e+01,
#          1.60419712e+01,   1.67538586e+01,   7.96267929e+01,
#          1.71777325e+01,   7.91460342e+01,   2.55272865e+01,
#          3.04494972e+01,   7.38192596e+01,   1.98773937e+01,
#          1.42237120e+01,   1.14848270e+01,   1.64897480e+01,
#          1.32013550e+01,   1.93373032e+01,   2.25063362e+01,
#          4.07369957e+01,   7.14856644e+01,   1.32133398e+01,
#          6.69588928e+01,   1.68021851e+01,   6.77594299e+01,
#          3.55287170e+01,   1.30429211e+01,   3.36260567e+01,
#          2.56725273e+01,   7.95145645e+01,   2.31113834e+01,
#          1.37091141e+01,   2.14453316e+01,   1.71233826e+01,
#          3.11847973e+01,   3.18794746e+01,   4.27363586e+01,
#          2.47340813e+01,   1.53574591e+01,   3.20441704e+01,
#          1.63275909e+01,   3.08042831e+01,   3.27254333e+01,
#          7.18410034e+01,   1.24692831e+01,   4.31279755e+01,
#          5.55191841e+01,   3.14110336e+01,   3.04828243e+01,
#          3.35406418e+01,   1.65995026e+01,   7.34228363e+01,
#          1.56650200e+01,   3.45888367e+01,   7.31595993e+01,
#          1.60686531e+01,   2.89320126e+01,   2.24033470e+01,
#          3.35046158e+01,   1.68930473e+01,   2.49195080e+01,
#          3.29725037e+01,   7.95249329e+01,   3.63269043e+01,
#          2.84036674e+01,   3.11975613e+01,   2.90178452e+01,
#          2.99383392e+01,   3.14438972e+01,   1.40609951e+01,
#          2.52251968e+01,   3.02897034e+01,   2.83955154e+01,
#          7.97117004e+01,   1.35811729e+01,   1.69262180e+01,
#          7.30524750e+01,   4.34313354e+01,   3.03081036e+01,
#          7.12908630e+01,   3.39372330e+01,   1.22640324e+01,
#          1.63133240e+01,   3.33658943e+01,   3.32996521e+01,
#          2.55537262e+01,   1.89405212e+01,   1.53909912e+01,
#          3.41127701e+01,   3.81409531e+01,   4.27941704e+01,
#          1.79490547e+01,   1.47964773e+01,   1.42576752e+01,
#          6.27966385e+01,   2.25143700e+01,   2.17344608e+01,
#          1.67090988e+01,   3.95347824e+01,   4.55086136e+01,
#          2.67340965e+01,   7.78771362e+01,   7.78771362e+01,
#          2.92556229e+01,   5.14459000e+01,   1.73071194e+01,
#          2.01031761e+01,   1.58735352e+01,   7.40975723e+01,
#          2.50640755e+01,   3.45135117e+01,   1.42893782e+01,
#          3.44382210e+01,   3.75920372e+01,   7.03011475e+01,
#          3.45155067e+01,   1.49447670e+01,   1.60297279e+01,
#          1.62671776e+01,   3.20306625e+01,   1.68690758e+01,
#          1.36017809e+01,   7.22129898e+01,   3.97410278e+01,
#          2.55001793e+01,   6.61238098e+01,   4.26111755e+01,
#          2.02713833e+01,   3.11880779e+01,   3.49814339e+01,
#          3.80809021e+01,   3.35046158e+01,   2.79844036e+01,
#          2.88992519e+01,   1.40701923e+01,   4.57856865e+01,
#          2.24015198e+01,   3.12869434e+01,   1.24612045e+01,
#          4.02349854e+01,   2.90128021e+01,   2.15947037e+01,
#          4.87879372e+01,   2.51898384e+01,   6.24001198e+01,
#          3.07506351e+01,   1.71275997e+01,   3.07641411e+01,
#          1.99178123e+01,   3.41250305e+01,   2.22873707e+01,
#          1.97835636e+01,   6.58383865e+01,   1.62361164e+01,
#          2.53307629e+01,   2.98092957e+01,   3.39751053e+01,
#          3.23136292e+01,   2.74127197e+01,   5.75664558e+01,
#          7.05888519e+01,   1.46774740e+01,   7.59721603e+01,
#          3.09749222e+01,   7.38246689e+01,   4.57702103e+01,
#          3.26699944e+01,   2.93734932e+01,   1.80673943e+01,
#          2.16834221e+01,   3.51603508e+01,   1.92289162e+01,
#          1.65497150e+01,   3.75601959e+01,   1.31947956e+01,
#          2.81903362e+01,   2.05289593e+01,   3.30399933e+01,
#          1.44067574e+01,   3.70371628e+01,   2.81536598e+01,
#          3.37402306e+01,   3.62036057e+01,   7.09775925e+01,
#          1.60018482e+01,   7.39172821e+01,   3.07762012e+01,
#          3.14628468e+01,   2.16754551e+01,   1.38606110e+01,
#          4.87389488e+01,   4.17732697e+01,   5.75737991e+01,
#          3.95894318e+01,   3.25691681e+01,   1.14440794e+01,
#          2.80961246e+01,   1.87142906e+01,   3.11150017e+01,
#          6.10586433e+01,   7.95931778e+01,   2.73683071e+01,
#          1.59875841e+01,   3.19165363e+01,   7.65613327e+01,
#          3.04591179e+01,   1.68562279e+01,   1.90611191e+01,
#          1.35899200e+01,   3.70575562e+01,   7.61138687e+01,
#          2.86936703e+01,   3.43576393e+01,   2.63364067e+01,
#          1.53565845e+01,   2.68609791e+01,   1.37772284e+01,
#          2.30129204e+01,   7.40506592e+01,   1.47467251e+01,
#          7.26905899e+01,   3.09137974e+01,   3.06281853e+01,
#          3.07824326e+01,   2.60737724e+01,   3.20025902e+01,
#          3.33580933e+01,   3.12079144e+01,   7.19047394e+01,
#          3.17156162e+01,   1.37574844e+01,   1.46358004e+01,
#          3.14505882e+01,   4.78648376e+01,   3.11032906e+01,
#          3.08668289e+01,   3.67473145e+01,   2.49880695e+01,
#          7.23491821e+01,   3.35103951e+01,   2.75404453e+01,
#          7.44214859e+01,   3.48703537e+01,   3.50603828e+01,
#          2.46952133e+01,   6.03741837e+01,   5.85632629e+01,
#          6.16819687e+01,   7.29747238e+01,   3.15170841e+01,
#          3.01967907e+01,   3.54164963e+01,   3.79273415e+01,
#          1.40567570e+01,   3.09343452e+01,   2.84882889e+01,
#          3.13921471e+01,   6.68234024e+01,   7.48221207e+01,
#          2.24904900e+01,   4.07287292e+01,   4.17107430e+01,
#          2.77000542e+01,   7.24272690e+01,   1.65219498e+01,
#          7.97297592e+01,   3.23382187e+01,   1.82986450e+01,
#          1.64139442e+01,   2.74108391e+01,   3.03382854e+01,
#          1.33772936e+01,   7.62419434e+01,   3.06274567e+01,
#          1.78084221e+01,   4.92455444e+01,   2.74225349e+01,
#          7.41718979e+01,   7.76537170e+01,   2.22068977e+01,
#          7.07797394e+01,   7.54794846e+01,   7.52970734e+01,
#          7.98520966e+01,   3.55600739e+01,   3.55866966e+01,
#          3.23029861e+01,   3.13296509e+01,   3.89119644e+01,
#          1.50457401e+01,   4.42889481e+01,   1.66921349e+01,
#          3.24717903e+01,   3.78147392e+01,   1.59834480e+01,
#          4.06152267e+01,   2.54983597e+01,   1.45294561e+01,
#          1.65784893e+01,   3.45685539e+01,   3.67844200e+01,
#          1.49760857e+01,   3.04633179e+01,   1.45401688e+01,
#          2.77293873e+01,   2.00639763e+01,   1.90822449e+01,
#          1.60038147e+01,   1.30267677e+01,   2.98601341e+01,
#          1.40285187e+01,   1.80545540e+01,   2.87448387e+01,
#          3.69366570e+01,   3.44627228e+01,   3.88673706e+01,
#          1.42707214e+01,   4.12881355e+01,   2.98693695e+01,
#          3.51635475e+01,   3.19614449e+01,   3.27273636e+01,
#          1.51909513e+01,   1.55177917e+01,   1.75656624e+01,
#          4.61936646e+01,   1.58254395e+01,   3.14996204e+01,
#          3.06131382e+01,   3.08135223e+01,   7.24935455e+01,
#          3.29742508e+01,   3.27174187e+01,   2.55862198e+01,
#          1.63622017e+01,   3.86103210e+01,   7.42066574e+01,
#          1.48663492e+01,   1.72023315e+01,   2.82763824e+01,
#          1.31790037e+01,   2.25521088e+01,   3.59805374e+01,
#          2.31548996e+01], dtype=float32)

# %%
order = np.argsort(sumDistance)
order
# Out:
# array([ 30,   1, 208, 491, 310,   4, 224, 124, 377, 263, 434, 340,  80,
#        132, 604, 322, 636,  16, 470, 312, 317, 567, 180, 370, 227, 504,
#        417, 113, 327, 526, 512, 485,  82, 606, 549, 365, 430, 198, 156,
#         83, 309, 389, 612, 407,  85, 108, 474, 116, 593, 599, 135, 299,
#        117, 527, 457, 515, 388, 280, 225, 633,  66, 175, 412, 597, 585,
#          6, 278, 618, 199,  48, 165, 510, 334, 383, 168, 619, 279, 348,
#        150, 219,  22, 189, 622,  14, 403,  25, 590, 498, 480, 603, 413,
#        300, 351,  75,  72, 213, 449, 414, 112, 378, 336, 630,   9, 244,
#        564, 271, 261, 311, 241, 560, 468, 166, 594, 285, 106, 346, 587,
#        393, 301, 319, 190, 502, 283, 416,  42, 355, 371,  11, 289, 196,
#         90, 147,  65, 329, 442, 303, 634,  29, 170, 401, 272,  10,  36,
#        620, 160, 164, 149, 570, 205, 129, 387, 607, 464, 183, 174, 243,
#        203, 563, 267,  23,  64, 233, 493,  68, 217, 382,  95, 503, 602,
#        206, 467, 313, 111, 447, 128, 195, 308, 444, 601, 402, 423, 270,
#        472,  94, 102, 246,  56, 328, 191, 437, 179, 484, 465, 392, 252,
#        575,  18, 446, 432, 353, 555, 314, 133, 391, 637,  31, 231, 221,
#        513, 326, 639,  57,  28,  98,  62, 250, 257, 172, 187, 540,  87,
#        333, 356, 533, 405, 439, 366, 450, 169, 167, 592, 420,  69, 305,
#        381, 629, 216, 324, 185,  49, 520, 162, 202, 238, 509, 130,  81,
#        396, 511,  37, 245,  26, 497, 565, 454, 572, 536, 126, 558, 600,
#        428, 492, 177, 235, 476, 471, 635, 368, 360, 551, 507, 608,   0,
#        429, 200, 352, 436, 362, 399, 463, 138, 251, 136,  71, 248,  59,
#         50,  33, 104, 218, 451, 605, 614, 363,  97,  38,  34, 546,  55,
#        146, 367, 374, 566,  45, 306, 501, 598,  79, 344, 273, 624, 569,
#        518, 255, 148, 441, 443, 482, 519, 337, 625, 531, 277, 517, 550,
#          7, 459,  54, 295, 220, 530,  40, 494, 232,  35, 330, 424, 361,
#        523, 433, 583, 192, 274, 552, 343, 364, 151, 528, 483, 194, 623,
#        110, 545, 109,  43,  19, 525, 291,   8, 331, 223, 499, 616, 215,
#        521, 415, 335,  96, 268, 582, 453, 253, 140, 562,  52, 134,  32,
#        588, 276, 490,  44, 462, 628, 338, 617, 182, 163,  78, 357, 627,
#        473, 201, 380, 142, 100, 522, 379, 119,  46, 155, 118,  99, 427,
#        354, 535, 230, 345,  93, 139, 323,  92, 477, 207, 376,  89, 239,
#        452, 384, 445, 144, 237, 508, 178, 408, 610, 406, 411, 161, 282,
#        260, 595, 184, 349,  53, 123, 258, 538, 425,  84, 539,  63, 466,
#        615, 284, 292, 547, 103,  73, 145, 321, 580, 581, 121, 176, 131,
#        638, 294, 297, 478, 181, 359, 209, 197,  39, 532, 596, 609, 475,
#        505, 469, 409, 589, 548, 125, 426, 290, 385, 631, 611, 584, 394,
#        489,  77, 419, 435, 591, 556, 315, 236, 210, 613,   5, 557, 487,
#        173,  86,  27, 422, 332, 386, 152, 341, 373,  24, 586, 265, 395,
#         67, 461, 431, 262, 621, 242, 107, 115, 287, 247,  76, 269,  88,
#        529,  61, 486, 159, 438, 571, 127, 400, 254, 141, 342, 157,  13,
#        455, 488, 542,  15, 541, 495,  12, 543, 440, 390, 288, 298, 222,
#        228, 448, 421, 211,   3, 553, 318, 171,  60,  47, 320, 240, 264,
#        410, 456, 576,   2, 479, 212, 122,  51, 375, 259, 316, 339, 229,
#        524, 101, 234, 418,  41, 534, 105, 559, 188, 626, 516, 137, 544,
#         21, 372, 120, 350,  74, 154, 347, 296,  20,  70, 307, 460, 249,
#        481, 114, 514, 404, 573, 632, 186, 214, 537,  91, 256, 554, 281,
#        143,  17, 204, 578, 266, 577, 286, 458, 506, 568, 500,  58, 153,
#        275, 574, 397, 398, 226, 304, 193, 293, 325, 358, 496, 302, 369,
#        561, 579, 158])

# %%
fig, axes = plt.subplots(nrows=5, ncols=10, sharex=True, sharey=True, figsize=(20,4))
ind=0
for row in axes:
    for ax in row:
        img = X[order[ind]]
        ax.imshow(img.reshape((size[1], size[0])), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ind+=1

fig.tight_layout(pad=0.1)

# %% [markdown]
#  ## Salvar modelo plano

# %%
model.save('plano/conteineresencoder.tflearn')
# Out:
# INFO:tensorflow:/home/ivan/Estudo/NanoDegree/Buscador/plano/conteineresencoder.tflearn is not in all_model_checkpoint_paths. Manually adding it.

# %% [markdown]
#  ## Salvar modelo convolucional

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "conv/modelconv.ckpt")
print("Model saved in file: %s" % save_path)
# Out:
# Model saved in file: conv/modelconv.ckpt

# %% [markdown]
#  ## Salvar índice de imagens comprimidas

# %%
import pickle
with open('compressedconv.pkl', 'wb') as output:
        pickle.dump(compressed, output, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Check-point --- para uso em aplicações proceder conforme abaixo

# %%
from __future__ import division, print_function, absolute_import
import pickle
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image

size = (256, 120)
inputsize = size[0]*size[1]
home = '/home/ivan/Área de Trabalho/ajna/amostras/stamps/'
dest = os.path.join(home, 'resize/')

# %%
### Lista de índices
with open('compressed.pkl', 'rb') as input:
        compressed = pickle.load(input)

# %%
###Model Fully
import tflearn
from modelfully import *
model, encoder, decoder = modelfully1(inputsize)
model.load('plano/conteineresencoder.tflearn')
encoding_model = tflearn.DNN(encoder, session=model.session)

# %%
# Apenas caso compressed não seja recuperado de arquivo ou BD
#compressed = encoding_model.predict(X) 
listSearch = np.array(compressed, dtype=np.float32)
#listSearchBinaryCode = listaBinaria(listSearch)
print(listSearch)
print(listSearch.shape)
# Out:
# [[  4.8979311   -1.71843851   0.6896643  ...,   5.0415926    0.91827202
#     0.74138951]
#  [ 10.28980637  -5.08350325   0.13227902 ...,  10.27590561  -0.99783969
#     1.10521019]
#  [  7.21124077   0.81402886  -1.71107817 ...,   4.16334248   6.5722127
#     0.07531053]
#  ...,
#  [  7.44124365  -9.16010857 -18.22451401 ...,  12.17253876  -1.76780021
#    16.63276863]
#  [  4.28486919  -3.61073542  -0.98695868 ...,   5.17890978  -3.71957874
#    -0.52893442]
#  [  1.72815633   0.69283301  -0.60162765 ...,  11.49221802   1.32945895
#     0.8522715 ]]
# (652, 200)

# %%
##Busca model fully
from indexfunctions import *

# Aqui, na prática, a aplicação irá receber uma imagem e a transformar para procura
im = Image.open(os.path.join(dest,'CARU9773334.jpg'))
imagem = np.asarray(im).reshape(inputsize) / 255
#print(imagem)
encode_code =  np.array(encoding_model.predict([imagem]), dtype=np.float32)
#print(encode_code)
print(encode_code.shape)
order = montaListaOrdenadaEuclidean(listSearch, encode_code, encoding_model)
#order = montaListaOrdenadaHamming(listSearchBinaryCode, encode_code)
order
# Out:
# (1, 200)
# array([458, 460, 514, 554, 375, 506, 568, 122, 404, 186, 479, 249, 537,
#        266, 524, 137, 632, 543, 214,  58, 204, 418, 410, 578, 153, 339,
#        157,   3, 576, 574, 456,  47, 275, 481, 286, 316,   2, 114, 320,
#        559, 143, 120, 141, 211, 212,  60, 296, 421, 228,  17, 318, 154,
#        573, 372, 584, 240, 281, 298, 505, 307,  41, 448, 553,  21, 171,
#        626, 247, 621, 500, 390, 400, 210, 236, 459, 173, 638, 650, 181,
#        571, 586,  32, 264,  13, 335,   0, 557, 373, 207,  76,  33, 341,
#        422, 360, 486, 605,  52, 507,  61, 338, 273, 234, 463, 107, 645,
#        356, 256,  67, 115,  20,  40, 350, 265, 611, 544,  35,  70, 521,
#        426,  45, 497, 490,  96, 209, 221,  74, 475, 125, 131, 347, 532,
#        357, 321,  99, 142, 496, 613, 105, 469, 358, 359, 615, 471, 598,
#         53, 651, 343, 325, 424, 215, 624, 292,  92,  79, 545,  59, 290,
#        600, 177, 306, 589,  81, 368, 640,  39, 461, 627, 518,  91,  38,
#         43,  77, 580,  78, 134, 453,  54, 201, 349, 591, 525, 229, 345,
#         12,  97, 342, 155, 538, 230, 535,  49, 384, 547, 579, 274, 419,
#        494, 628, 476, 184, 399, 429, 139, 616, 550, 367, 440, 369, 163,
#        438, 380, 352, 643, 119, 130,  71, 276, 569, 323, 539, 562, 623,
#        462, 425, 441, 647, 161, 385, 519, 409, 483, 337, 297,  86, 235,
#        452, 530, 609, 561, 232, 528, 192, 534, 259, 194, 344, 121, 185,
#        302, 595, 551,  55, 109, 610, 588, 140, 394, 293, 146, 188, 363,
#        220, 473,  93, 133, 433, 144, 361, 193, 176, 152,  51, 145, 629,
#        284,  73, 162, 516,  11, 216, 364, 552, 443, 200, 566, 492, 295,
#        577, 436, 501, 260, 415, 428, 391, 291, 239,  46, 517, 197,  44,
#        103, 435, 499, 641, 101,  28, 159,  23, 294, 246, 304, 182, 237,
#         31,  63, 451, 362, 405, 270, 413, 336, 607, 617, 482,  18, 315,
#        556, 199, 158, 331, 397, 398,  90, 382, 487, 314,  82, 178,  57,
#        630, 503, 226, 454, 288,  66, 489, 206, 332, 520, 267,  84, 330,
#        608, 231, 205, 179, 407, 324, 467, 533, 432, 606, 563, 639, 396,
#        522, 305, 446, 439,  87, 334, 511, 567, 149, 271, 585, 262, 353,
#        208,  42, 313, 555, 491, 377, 431, 602, 213,   1, 601,  56, 593,
#        258, 637, 648, 420, 508, 635, 575, 386,  94, 526, 546, 592, 381,
#        333, 529,   4, 132, 308, 549,  48, 612, 540, 224, 510,  69, 242,
#        138, 470,  98, 252, 263, 395,  83,  88, 513, 564, 636, 604, 128,
#        328, 167, 370, 620, 172, 536, 102, 558, 450, 277, 434, 646, 118,
#        268, 280, 570, 170, 300, 250, 512, 322, 619, 416,  85,  19, 310,
#        312,  95, 183, 113, 480, 379, 299, 631, 255, 106, 327, 388, 165,
#        317, 408, 371, 223, 406, 466, 423,  80, 531, 430, 523, 127,  24,
#        478,  72, 117, 135,  37, 175, 219,  25, 485, 472, 166, 633, 241,
#        156,   9, 504, 225,  36,  16,  65, 278, 642, 365, 594, 198, 244,
#        498, 376, 560, 111, 468, 227, 147, 174, 124, 168, 190, 465, 340,
#        191, 301, 309, 402,  14,  22, 346, 279, 108, 351, 129, 596, 401,
#        414, 548, 587,  75, 383, 634, 403, 326, 412, 442, 311, 457, 622,
#        449, 355, 447, 123, 202, 217, 116, 411, 599, 329, 474, 283, 417,
#        169, 603, 196, 378, 644, 319, 437, 261, 112,  29, 583,   8, 189,
#        348, 150, 527, 392, 180, 104, 597, 243, 565, 245, 164, 515, 502,
#        285, 272, 445, 581, 289, 253, 282, 618, 160,  68, 393,  10, 477,
#         62, 444, 257, 493, 148, 464,   6, 238, 389, 151, 251, 187, 233,
#        387, 248,  30, 374, 614,  64, 484,  89, 541,  27, 287, 126, 488,
#        649, 509, 366, 625,  34,  15, 455,   7, 582, 218, 572, 136, 269,
#        195, 542, 495,  50, 303, 100, 110, 254, 427, 354, 203,  26, 590,
#        222,   5])

# %%
###Model Convolutional
import tensorflow as tf
from modelconv import *
encoded, decoded, loss, cost, opt = modelconv1(size)
saver = tf.train.Saver()

with tf.Session() as sess:
  # Restore variables from disk.
  saver.restore(sess, "conv/modelconv.ckpt")

# %% [markdown]
#  ## Testar imagens A, B, C, D, E, F, G

# %%
# %matplotlib inline
import glob
inputsize = size[0]*size[1]

numarquivos = len([name for name in os.listdir('imgnotebook') if name.endswith('png')])
X = np.ndarray(shape=(numarquivos, inputsize), dtype=np.float32)
print(X.shape)

cont = 0
for file in glob.glob(os.path.join('imgnotebook','*.png')):
    print(file)
    im = Image.open(file).convert('L')
    X[cont] = np.asarray(im).reshape(inputsize)
    cont +=1

f, a = plt.subplots(2, 3, figsize=(15, 5))
for i in range(3):
    a[0][i].imshow(np.reshape(X[i], (size[1], size[0])), cmap='gray')
    a[1][i].imshow(np.reshape(X[i+3], (size[1], size[0])), cmap='gray')
f.show()
plt.draw()
# Out:
# (7, 30720)
# imgnotebook/exemplovazio.png
# imgnotebook/exemplocaixa1.png
# imgnotebook/exemplocaixa1espelhado.png
# imgnotebook/exemplocaixa2.png
# imgnotebook/exemplocirculoespelhado.png
# imgnotebook/exemplocaixa2espelhado.png
# imgnotebook/exemplocirculo.png
# /usr/lib/python3/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
### Para realizar testes com a rede plana
compressed = encoding_model.predict(X) 
listSearch = np.array(compressed, dtype=np.float32)
#listSearchBinaryCode = listaBinaria(listSearch)
print(listSearch)
print(listSearch.shape)
# Out:
# [[ -5.23029175e+02   4.08600983e+02  -1.68050049e+02 ...,  -4.00533643e+03
#     2.30781177e+03  -7.31271790e+02]
#  [ -5.49579834e+02   3.26271515e+02  -2.44342087e+02 ...,  -4.07306104e+03
#     2.08900391e+03  -7.85239502e+02]
#  [ -5.08350311e+02   4.20053650e+02  -2.62586121e+02 ...,  -3.88084497e+03
#     2.22534888e+03  -5.99221985e+02]
#  ...,
#  [ -1.07302551e+03  -2.54709351e+02  -8.76599487e+02 ...,  -3.21856982e+03
#     1.26100732e+03  -1.39939102e+02]
#  [ -4.10888916e+02   3.02861511e+02  -7.77277893e+02 ...,  -3.50393018e+03
#     1.63883240e+03  -4.44011505e+02]
#  [ -8.64821594e+02   1.32355945e+03   3.74686766e+00 ...,  -3.36032324e+03
#     3.15531421e+03  -1.21568994e+03]]
# (7, 200)

# %%
### Para realizar testes com a rede convolucional
imgSearch = X.reshape((-1, size[1], size[0], 1))
listSearch = np.array(sess.run([encoded], feed_dict={inputs_: imgSearch})).reshape(-1, 256)

print(listSearch)
print(listSearch.shape)
# Out:
# [[  0.           0.          52.77127838 ...,   0.           0.
#    10.03362274]
#  [  0.           0.          52.70506668 ...,   0.           0.           8.9855299 ]
#  [  0.           0.          52.70506668 ...,   0.           0.
#     8.85794735]
#  ...,
#  [  0.           0.          52.99953842 ...,   0.           0.           9.6234951 ]
#  [  0.           0.          52.59076309 ...,   0.           0.
#     9.08255959]
#  [  0.           0.          52.77127838 ...,   0.           0.
#     6.57945108]]
# (7, 256)

# %%
from indexfunctions import *

def testeCaixas(pX, plano=True):
    if plano:
        imgSearch = encoding_model.predict(pX)
    else:
        img = pX.reshape((-1, size[1], size[0], 1))
        imgSearch = np.array(sess.run([encoded], feed_dict={inputs_: img})).reshape(-1, 256)
    
    print(listSearch.shape)
    order = montaListaOrdenadaEuclidean(listSearch, imgSearch) 
    print(order)
    Xorder = X[order]
    f, a = plt.subplots(2, 3, figsize=(15, 5))
    for i in range(3):
        a[0][i].imshow(np.reshape(Xorder[i], (size[1], size[0])), cmap='gray')
        a[1][i].imshow(np.reshape(Xorder[i+3], (size[1], size[0])), cmap='gray')
    f.show()
    plt.draw()
    
Xloc = X[1]  # Caixa pequena esquerda
testeCaixas(Xloc, False)
# Out:
# (7, 256)
# [1 2 3 5 0 6 4]
# /usr/lib/python3/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
order = montaListaOrdenadaEuclidean(listSearch, X[4], encoding_model) # Círculo esquerda
print(order)
Xorder = X[order]
f, a = plt.subplots(2, 3, figsize=(15, 5))
for i in range(3):
    a[0][i].imshow(np.reshape(Xorder[i], (size[1], size[0])), cmap='gray')
    a[1][i].imshow(np.reshape(Xorder[i+3], (size[1], size[0])), cmap='gray')
f.show()
plt.draw()
# Out:
# [4 5 2 0 1 3 6]
# /usr/lib/python3/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
Xloc = X[3]  # Caixa pequena esquerda
testeCaixas(Xloc, False)
# Out:
# (7, 256)
# [3 1 2 5 0 6 4]
# /usr/lib/python3/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
order = montaListaOrdenadaEuclidean(listSearch, X[6], encoding_model) # Círculo esquerda
print(order)
Xorder = X[order]
f, a = plt.subplots(2, 3, figsize=(15, 5))
for i in range(3):
    a[0][i].imshow(np.reshape(Xorder[i], (size[1], size[0])), cmap='gray')
    a[1][i].imshow(np.reshape(Xorder[i+3], (size[1], size[0])), cmap='gray')
f.show()
plt.draw()
# Out:
# [6 3 1 0 2 5 4]
# /usr/lib/python3/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
#  ## Os testes com as imagens fabricadas foram muito bem, conforme acima, parece que o Encoder foi capaz de aprender volume, formato, distribuição. Mas, como previsto, parece que a posição dos objetos determina o resultado. Testar com convolucional para ver se consegue ficar independente da posição dos objetos.

# %% [markdown]
#  ## Teste com convolucional em 30/06/2017 não apresentou resultados melhores. Testar treinamento de ambas as redes com mais dados e com encoders ligeiramente maiores no futuro.
